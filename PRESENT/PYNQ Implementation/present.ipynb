# %% [markdown]
# # PRESENT CRYPTOGRAPHIC CORE TESTBENCH

# %% [markdown]
# This testbench takes in 7 testcases generated based on the PRESENT Cryptographic Algorithm paper, and checks whether the hardware implemented produces the correct results.

# %%
from pynq import Overlay
import numpy as np
from pynq import Xlnk
from pynq.lib import dma

# %%
#7 testcases
key_high1 = 0X000000000000FFFF
key_low1 = 0XFFFFFFFFFFFFFFFF
block1 = 0X0000000000000000
golden_cipher1 =0XE72C46C0F5945049

key_high2 = 0X0000000000002D3C
key_low2 = 0X4B5A6978AFED09A2
block2 = 0X797368656C646F6E
golden_cipher2 = 0X78565173E21A9B11

key_high3 = 0X0000000000002D3C
key_low3 = 0X4B5A6978AFED09A2
block3 = 0X73616E646965676F
golden_cipher3 = 0X883EB1649D771AA7

key_high4 = 0X0000000000002D3C
key_low4 = 0X4B5A6978AFED09A2
block4 = 0X6368657363616B65
golden_cipher4 = 0X079CEC86DBBACC74

key_high5 = 0X0000000000002D3C
key_low5 = 0X4B5A6978AFED09A2
block5 = 0X746F6D6A65727279
golden_cipher5 = 0XB21DA5DB83192787

key_high6 = 0X0000000000002D3C
key_low6 = 0X4B5A6978AFED09A2
block6 = 0X6861636B726D616E
golden_cipher6 = 0XE289A84B226748E7

key_high7 = 0X0000000000000000
key_low7 = 0X0000000000000000
block7 = 0X0000000000000000
golden_cipher7 = 0X5579C1387B228445

#number of samples sent each time
NUM_SAMPLES = 1

# %%
ol=Overlay('/home/xilinx/jupyter_notebooks/present_core/design_1_wrapper.bit')

# %%
dma0 = ol.present.axi_dma_0
dma1 = ol.present.axi_dma_1
dma2 = ol.present.axi_dma_2

# %%
xlnk = Xlnk()
keyhigh_in1= xlnk.cma_array(shape=(NUM_SAMPLES,), dtype=np.uint64) 
keylow_in1 = xlnk.cma_array(shape=(NUM_SAMPLES,), dtype=np.uint64)           
block_in1 = xlnk.cma_array(shape=(NUM_SAMPLES,), dtype=np.uint64) 
cipher_out1 = xlnk.cma_array(shape=(NUM_SAMPLES,), dtype=np.uint64)
np.copyto(keyhigh_in1, key_high1)
np.copyto(keylow_in1, key_low1)
np.copyto(block_in1, block1)

keyhigh_in2= xlnk.cma_array(shape=(NUM_SAMPLES,), dtype=np.uint64) 
keylow_in2 = xlnk.cma_array(shape=(NUM_SAMPLES,), dtype=np.uint64)           
block_in2 = xlnk.cma_array(shape=(NUM_SAMPLES,), dtype=np.uint64) 
cipher_out2 = xlnk.cma_array(shape=(NUM_SAMPLES,), dtype=np.uint64)
np.copyto(keyhigh_in2, key_high2)
np.copyto(keylow_in2, key_low2)
np.copyto(block_in2, block2)

keyhigh_in3= xlnk.cma_array(shape=(NUM_SAMPLES,), dtype=np.uint64) 
keylow_in3 = xlnk.cma_array(shape=(NUM_SAMPLES,), dtype=np.uint64)           
block_in3 = xlnk.cma_array(shape=(NUM_SAMPLES,), dtype=np.uint64) 
cipher_out3 = xlnk.cma_array(shape=(NUM_SAMPLES,), dtype=np.uint64)
np.copyto(keyhigh_in3, key_high3)
np.copyto(keylow_in3, key_low3)
np.copyto(block_in3, block3)

keyhigh_in4= xlnk.cma_array(shape=(NUM_SAMPLES,), dtype=np.uint64) 
keylow_in4 = xlnk.cma_array(shape=(NUM_SAMPLES,), dtype=np.uint64)           
block_in4 = xlnk.cma_array(shape=(NUM_SAMPLES,), dtype=np.uint64) 
cipher_out4 = xlnk.cma_array(shape=(NUM_SAMPLES,), dtype=np.uint64)
np.copyto(keyhigh_in4, key_high4)
np.copyto(keylow_in4, key_low4)
np.copyto(block_in4, block4)

keyhigh_in5= xlnk.cma_array(shape=(NUM_SAMPLES,), dtype=np.uint64) 
keylow_in5 = xlnk.cma_array(shape=(NUM_SAMPLES,), dtype=np.uint64)           
block_in5 = xlnk.cma_array(shape=(NUM_SAMPLES,), dtype=np.uint64) 
cipher_out5 = xlnk.cma_array(shape=(NUM_SAMPLES,), dtype=np.uint64)
np.copyto(keyhigh_in5, key_high5)
np.copyto(keylow_in5, key_low5)
np.copyto(block_in5, block5)

keyhigh_in6= xlnk.cma_array(shape=(NUM_SAMPLES,), dtype=np.uint64) 
keylow_in6 = xlnk.cma_array(shape=(NUM_SAMPLES,), dtype=np.uint64)           
block_in6 = xlnk.cma_array(shape=(NUM_SAMPLES,), dtype=np.uint64) 
cipher_out6 = xlnk.cma_array(shape=(NUM_SAMPLES,), dtype=np.uint64)
np.copyto(keyhigh_in6, key_high6)
np.copyto(keylow_in6, key_low6)
np.copyto(block_in6, block6)

keyhigh_in7= xlnk.cma_array(shape=(NUM_SAMPLES,), dtype=np.uint64) 
keylow_in7 = xlnk.cma_array(shape=(NUM_SAMPLES,), dtype=np.uint64)           
block_in7 = xlnk.cma_array(shape=(NUM_SAMPLES,), dtype=np.uint64) 
cipher_out7 = xlnk.cma_array(shape=(NUM_SAMPLES,), dtype=np.uint64)
np.copyto(keyhigh_in7, key_high7)
np.copyto(keylow_in7, key_low7)
np.copyto(block_in7, block7)

# %%
present_ip = ol.present.present_encrypt_0
present_ip.write(0x00,1)
# Start the DMA send and recv channels.
dma0.recvchannel.start()
dma0.sendchannel.start()
dma1.sendchannel.start()
dma2.sendchannel.start()
dma0.sendchannel.transfer(keyhigh_in1)
dma1.sendchannel.transfer(keylow_in1)
dma2.sendchannel.transfer(block_in1)
dma0.recvchannel.transfer(cipher_out1)      
# Wait for the DMA to send and recv data.
dma0.recvchannel.wait()
dma0.sendchannel.wait()
dma1.sendchannel.wait()
dma2.sendchannel.wait()

present_ip = ol.present.present_encrypt_0
present_ip.write(0x00,1)
# Start the DMA send and recv channels.
dma0.recvchannel.start()
dma0.sendchannel.start()
dma1.sendchannel.start()
dma2.sendchannel.start()
dma0.sendchannel.transfer(keyhigh_in2)
dma1.sendchannel.transfer(keylow_in2)
dma2.sendchannel.transfer(block_in2)
dma0.recvchannel.transfer(cipher_out2)      
# Wait for the DMA to send and recv data.
dma0.recvchannel.wait()
dma0.sendchannel.wait()
dma1.sendchannel.wait()
dma2.sendchannel.wait()

present_ip = ol.present.present_encrypt_0
present_ip.write(0x00,1)
# Start the DMA send and recv channels.
dma0.recvchannel.start()
dma0.sendchannel.start()
dma1.sendchannel.start()
dma2.sendchannel.start()
dma0.sendchannel.transfer(keyhigh_in3)
dma1.sendchannel.transfer(keylow_in3)
dma2.sendchannel.transfer(block_in3)
dma0.recvchannel.transfer(cipher_out3)      
# Wait for the DMA to send and recv data.
dma0.recvchannel.wait()
dma0.sendchannel.wait()
dma1.sendchannel.wait()
dma2.sendchannel.wait()

present_ip = ol.present.present_encrypt_0
present_ip.write(0x00,1)
# Start the DMA send and recv channels.
dma0.recvchannel.start()
dma0.sendchannel.start()
dma1.sendchannel.start()
dma2.sendchannel.start()
dma0.sendchannel.transfer(keyhigh_in4)
dma1.sendchannel.transfer(keylow_in4)
dma2.sendchannel.transfer(block_in4)
dma0.recvchannel.transfer(cipher_out4)      
# Wait for the DMA to send and recv data.
dma0.recvchannel.wait()
dma0.sendchannel.wait()
dma1.sendchannel.wait()
dma2.sendchannel.wait()

present_ip = ol.present.present_encrypt_0
present_ip.write(0x00,1)
# Start the DMA send and recv channels.
dma0.recvchannel.start()
dma0.sendchannel.start()
dma1.sendchannel.start()
dma2.sendchannel.start()
dma0.sendchannel.transfer(keyhigh_in5)
dma1.sendchannel.transfer(keylow_in5)
dma2.sendchannel.transfer(block_in5)
dma0.recvchannel.transfer(cipher_out5)      
# Wait for the DMA to send and recv data.
dma0.recvchannel.wait()
dma0.sendchannel.wait()
dma1.sendchannel.wait()
dma2.sendchannel.wait()

present_ip = ol.present.present_encrypt_0
present_ip.write(0x00,1)
# Start the DMA send and recv channels.
dma0.recvchannel.start()
dma0.sendchannel.start()
dma1.sendchannel.start()
dma2.sendchannel.start()
dma0.sendchannel.transfer(keyhigh_in6)
dma1.sendchannel.transfer(keylow_in6)
dma2.sendchannel.transfer(block_in6)
dma0.recvchannel.transfer(cipher_out6)      
# Wait for the DMA to send and recv data.
dma0.recvchannel.wait()
dma0.sendchannel.wait()
dma1.sendchannel.wait()
dma2.sendchannel.wait()

present_ip = ol.present.present_encrypt_0
present_ip.write(0x00,1)
# Start the DMA send and recv channels.
dma0.recvchannel.start()
dma0.sendchannel.start()
dma1.sendchannel.start()
dma2.sendchannel.start()
dma0.sendchannel.transfer(keyhigh_in7)
dma1.sendchannel.transfer(keylow_in7)
dma2.sendchannel.transfer(block_in7)
dma0.recvchannel.transfer(cipher_out7)      
# Wait for the DMA to send and recv data.
dma0.recvchannel.wait()
dma0.sendchannel.wait()
dma1.sendchannel.wait()
dma2.sendchannel.wait()

# %% [markdown]
# # Verifying the outputs

# %%
i = 0
print("Testcase - 1")
print("80-bit Key",hex(key_high1), hex(key_low1))
print("64-bit Plain Text", hex(block1))
print("64-bit Golden Cipher", hex(golden_cipher1))
print("64-bit Computed Cipher", hex(cipher_out1[0]))
if(cipher_out1[0] == golden_cipher1):
    i = i + 1
print("\n")
print("Testcase - 2")
print("80-bit Key",hex(key_high2), hex(key_low2))
print("64-bit Plain Text", hex(block2))
print("64-bit Golden Cipher", hex(golden_cipher2))
print("64-bit Computed Cipher", hex(cipher_out2[0]))
if(cipher_out2[0] == golden_cipher2):
      i = i + 1
print("\n")
print("Testcase - 3")
print("80-bit Key",hex(key_high3), hex(key_low3))
print("64-bit Plain Text", hex(block3))
print("64-bit Golden Cipher", hex(golden_cipher3))
print("64-bit Computed Cipher", hex(cipher_out3[0]))
if(cipher_out3[0] == golden_cipher3):
      i = i + 1
print("\n")
print("Testcase - 4")
print("80-bit Key",hex(key_high4), hex(key_low4))
print("64-bit Plain Text", hex(block4))
print("64-bit Golden Cipher", hex(golden_cipher4))
print("64-bit Computed Cipher", hex(cipher_out4[0]))
if(cipher_out4[0] == golden_cipher4):
      i = i + 1
print("\n")
print("Testcase - 5")
print("80-bit Key",hex(key_high5), hex(key_low5))
print("64-bit Plain Text", hex(block5))
print("64-bit Golden Cipher", hex(golden_cipher5))
print("64-bit Computed Cipher", hex(cipher_out5[0]))
if(cipher_out5[0] == golden_cipher5):
      i = i + 1
print("\n")
print("Testcase - 6")
print("80-bit Key",hex(key_high6), hex(key_low6))
print("64-bit Plain Text", hex(block6))
print("64-bit Golden Cipher", hex(golden_cipher6))
print("64-bit Computed Cipher", hex(cipher_out6[0]))
if(cipher_out6[0] == golden_cipher6):
    i = i + 1
print("\n")
print("Testcase - 7")
print("80-bit Key",hex(key_high7), hex(key_low7))
print("64-bit Plain Text", hex(block7))
print("64-bit Golden Cipher", hex(golden_cipher7))
print("64-bit Computed Cipher", hex(cipher_out7[0]))
if(cipher_out7[0] == golden_cipher7):
      i = i + 1

print("\n")
if(i==7):
    print("All Outputs Match, This PRESENT CORE WORKS!!!")
else:
    print("The PRESENT Core has some problem!!!")
# Out:
# Testcase - 1
# 80-bit Key 0xffff 0xffffffffffffffff
# 64-bit Plain Text 0x0
# 64-bit Golden Cipher 0xe72c46c0f5945049
# 64-bit Computed Cipher 0xe72c46c0f5945049
#
#
# Testcase - 2
# 80-bit Key 0x2d3c 0x4b5a6978afed09a2
# 64-bit Plain Text 0x797368656c646f6e
# 64-bit Golden Cipher 0x78565173e21a9b11
# 64-bit Computed Cipher 0x78565173e21a9b11
#
#
# Testcase - 3
# 80-bit Key 0x2d3c 0x4b5a6978afed09a2
# 64-bit Plain Text 0x73616e646965676f
# 64-bit Golden Cipher 0x883eb1649d771aa7
# 64-bit Computed Cipher 0x883eb1649d771aa7
#
#
# Testcase - 4
# 80-bit Key 0x2d3c 0x4b5a6978afed09a2
# 64-bit Plain Text 0x6368657363616b65
# 64-bit Golden Cipher 0x79cec86dbbacc74
# 64-bit Computed Cipher 0x79cec86dbbacc74
#
#
# Testcase - 5
# 80-bit Key 0x2d3c 0x4b5a6978afed09a2
# 64-bit Plain Text 0x746f6d6a65727279
# 64-bit Golden Cipher 0xb21da5db83192787
# 64-bit Computed Cipher 0xb21da5db83192787
#
#
# Testcase - 6
# 80-bit Key 0x2d3c 0x4b5a6978afed09a2
# 64-bit Plain Text 0x6861636b726d616e
# ...
